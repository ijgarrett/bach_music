# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from music21 import stream, chord
import os

# %%
df = pd.read_csv("chorales/train/chorale_000.csv")

# %%
df
# each row in the CSV is one time step in the chorale
# each column is one voice
# Out:
#      note0  note1  note2  note3
# 0       74     70     65     58
# 1       74     70     65     58
# 2       74     70     65     58
# 3       74     70     65     58
# 4       75     70     58     55
# ..     ...    ...    ...    ...
# 187     70     65     62     46
# 188     70     65     62     46
# 189     70     65     62     46
# 190     70     65     62     46
# 191     70     65     62     46
#
# [192 rows x 4 columns]

# %%
train_files = sorted([os.path.join("chorales", "train", f) for f in os.listdir(os.path.join("chorales", "train")) if f.endswith(".csv")])
test_files = sorted([os.path.join("chorales", "test", f) for f in os.listdir(os.path.join("chorales", "test")) if f.endswith(".csv")])
valid_files = sorted([os.path.join("chorales", "valid", f) for f in os.listdir(os.path.join("chorales", "valid")) if f.endswith(".csv")])

# %%
train_files
# Out:
# ['chorales\\train\\chorale_000.csv',
#  'chorales\\train\\chorale_001.csv',
#  'chorales\\train\\chorale_002.csv',
#  'chorales\\train\\chorale_003.csv',
#  'chorales\\train\\chorale_004.csv',
#  'chorales\\train\\chorale_005.csv',
#  'chorales\\train\\chorale_006.csv',
#  'chorales\\train\\chorale_007.csv',
#  'chorales\\train\\chorale_008.csv',
#  'chorales\\train\\chorale_009.csv',
#  'chorales\\train\\chorale_010.csv',
#  'chorales\\train\\chorale_011.csv',
#  'chorales\\train\\chorale_012.csv',
#  'chorales\\train\\chorale_013.csv',
#  'chorales\\train\\chorale_014.csv',
#  'chorales\\train\\chorale_015.csv',
#  'chorales\\train\\chorale_016.csv',
#  'chorales\\train\\chorale_017.csv',
#  'chorales\\train\\chorale_018.csv',
#  'chorales\\train\\chorale_019.csv',
#  'chorales\\train\\chorale_020.csv',
#  'chorales\\train\\chorale_021.csv',
#  'chorales\\train\\chorale_022.csv',
#  'chorales\\train\\chorale_023.csv',
#  'chorales\\train\\chorale_024.csv',
#  'chorales\\train\\chorale_025.csv',
#  'chorales\\train\\chorale_026.csv',
#  'chorales\\train\\chorale_027.csv',
#  'chorales\\train\\chorale_028.csv',
#  'chorales\\train\\chorale_029.csv',
#  'chorales\\train\\chorale_030.csv',
#  'chorales\\train\\chorale_031.csv',
#  'chorales\\train\\chorale_032.csv',
#  'chorales\\train\\chorale_033.csv',
#  'chorales\\train\\chorale_034.csv',
#  'chorales\\train\\chorale_035.csv',
#  'chorales\\train\\chorale_036.csv',
#  'chorales\\train\\chorale_037.csv',
#  'chorales\\train\\chorale_038.csv',
#  'chorales\\train\\chorale_039.csv',
#  'chorales\\train\\chorale_040.csv',
#  'chorales\\train\\chorale_041.csv',
#  'chorales\\train\\chorale_042.csv',
#  'chorales\\train\\chorale_043.csv',
#  'chorales\\train\\chorale_044.csv',
#  'chorales\\train\\chorale_045.csv',
#  'chorales\\train\\chorale_046.csv',
#  'chorales\\train\\chorale_047.csv',
#  'chorales\\train\\chorale_048.csv',
#  'chorales\\train\\chorale_049.csv',
#  'chorales\\train\\chorale_050.csv',
#  'chorales\\train\\chorale_051.csv',
#  'chorales\\train\\chorale_052.csv',
#  'chorales\\train\\chorale_053.csv',
#  'chorales\\train\\chorale_054.csv',
#  'chorales\\train\\chorale_055.csv',
#  'chorales\\train\\chorale_056.csv',
#  'chorales\\train\\chorale_057.csv',
#  'chorales\\train\\chorale_058.csv',
#  'chorales\\train\\chorale_059.csv',
#  'chorales\\train\\chorale_060.csv',
#  'chorales\\train\\chorale_061.csv',
#  'chorales\\train\\chorale_062.csv',
#  'chorales\\train\\chorale_063.csv',
#  'chorales\\train\\chorale_064.csv',
#  'chorales\\train\\chorale_065.csv',
#  'chorales\\train\\chorale_066.csv',
#  'chorales\\train\\chorale_067.csv',
#  'chorales\\train\\chorale_068.csv',
#  'chorales\\train\\chorale_069.csv',
#  'chorales\\train\\chorale_070.csv',
#  'chorales\\train\\chorale_071.csv',
#  'chorales\\train\\chorale_072.csv',
#  'chorales\\train\\chorale_073.csv',
#  'chorales\\train\\chorale_074.csv',
#  'chorales\\train\\chorale_075.csv',
#  'chorales\\train\\chorale_076.csv',
#  'chorales\\train\\chorale_077.csv',
#  'chorales\\train\\chorale_078.csv',
#  'chorales\\train\\chorale_079.csv',
#  'chorales\\train\\chorale_080.csv',
#  'chorales\\train\\chorale_081.csv',
#  'chorales\\train\\chorale_082.csv',
#  'chorales\\train\\chorale_083.csv',
#  'chorales\\train\\chorale_084.csv',
#  'chorales\\train\\chorale_085.csv',
#  'chorales\\train\\chorale_086.csv',
#  'chorales\\train\\chorale_087.csv',
#  'chorales\\train\\chorale_088.csv',
#  'chorales\\train\\chorale_089.csv',
#  'chorales\\train\\chorale_090.csv',
#  'chorales\\train\\chorale_091.csv',
#  'chorales\\train\\chorale_092.csv',
#  'chorales\\train\\chorale_093.csv',
#  'chorales\\train\\chorale_094.csv',
#  'chorales\\train\\chorale_095.csv',
#  'chorales\\train\\chorale_096.csv',
#  'chorales\\train\\chorale_097.csv',
#  'chorales\\train\\chorale_098.csv',
#  'chorales\\train\\chorale_099.csv',
#  'chorales\\train\\chorale_100.csv',
#  'chorales\\train\\chorale_101.csv',
#  'chorales\\train\\chorale_102.csv',
#  'chorales\\train\\chorale_103.csv',
#  'chorales\\train\\chorale_104.csv',
#  'chorales\\train\\chorale_105.csv',
#  'chorales\\train\\chorale_106.csv',
#  'chorales\\train\\chorale_107.csv',
#  'chorales\\train\\chorale_108.csv',
#  'chorales\\train\\chorale_109.csv',
#  'chorales\\train\\chorale_110.csv',
#  'chorales\\train\\chorale_111.csv',
#  'chorales\\train\\chorale_112.csv',
#  'chorales\\train\\chorale_113.csv',
#  'chorales\\train\\chorale_114.csv',
#  'chorales\\train\\chorale_115.csv',
#  'chorales\\train\\chorale_116.csv',
#  'chorales\\train\\chorale_117.csv',
#  'chorales\\train\\chorale_118.csv',
#  'chorales\\train\\chorale_119.csv',
#  'chorales\\train\\chorale_120.csv',
#  'chorales\\train\\chorale_121.csv',
#  'chorales\\train\\chorale_122.csv',
#  'chorales\\train\\chorale_123.csv',
#  'chorales\\train\\chorale_124.csv',
#  'chorales\\train\\chorale_125.csv',
#  'chorales\\train\\chorale_126.csv',
#  'chorales\\train\\chorale_127.csv',
#  'chorales\\train\\chorale_128.csv',
#  'chorales\\train\\chorale_129.csv',
#  'chorales\\train\\chorale_130.csv',
#  'chorales\\train\\chorale_131.csv',
#  'chorales\\train\\chorale_132.csv',
#  'chorales\\train\\chorale_133.csv',
#  'chorales\\train\\chorale_134.csv',
#  'chorales\\train\\chorale_135.csv',
#  'chorales\\train\\chorale_136.csv',
#  'chorales\\train\\chorale_137.csv',
#  'chorales\\train\\chorale_138.csv',
#  'chorales\\train\\chorale_139.csv',
#  'chorales\\train\\chorale_140.csv',
#  'chorales\\train\\chorale_141.csv',
#  'chorales\\train\\chorale_142.csv',
#  'chorales\\train\\chorale_143.csv',
#  'chorales\\train\\chorale_144.csv',
#  'chorales\\train\\chorale_145.csv',
#  'chorales\\train\\chorale_146.csv',
#  'chorales\\train\\chorale_147.csv',
#  'chorales\\train\\chorale_148.csv',
#  'chorales\\train\\chorale_149.csv',
#  'chorales\\train\\chorale_150.csv',
#  'chorales\\train\\chorale_151.csv',
#  'chorales\\train\\chorale_152.csv',
#  'chorales\\train\\chorale_153.csv',
#  'chorales\\train\\chorale_154.csv',
#  'chorales\\train\\chorale_155.csv',
#  'chorales\\train\\chorale_156.csv',
#  'chorales\\train\\chorale_157.csv',
#  'chorales\\train\\chorale_158.csv',
#  'chorales\\train\\chorale_159.csv',
#  'chorales\\train\\chorale_160.csv',
#  'chorales\\train\\chorale_161.csv',
#  'chorales\\train\\chorale_162.csv',
#  'chorales\\train\\chorale_163.csv',
#  'chorales\\train\\chorale_164.csv',
#  'chorales\\train\\chorale_165.csv',
#  'chorales\\train\\chorale_166.csv',
#  'chorales\\train\\chorale_167.csv',
#  'chorales\\train\\chorale_168.csv',
#  'chorales\\train\\chorale_169.csv',
#  'chorales\\train\\chorale_170.csv',
#  'chorales\\train\\chorale_171.csv',
#  'chorales\\train\\chorale_172.csv',
#  'chorales\\train\\chorale_173.csv',
#  'chorales\\train\\chorale_174.csv',
#  'chorales\\train\\chorale_175.csv',
#  'chorales\\train\\chorale_176.csv',
#  'chorales\\train\\chorale_177.csv',
#  'chorales\\train\\chorale_178.csv',
#  'chorales\\train\\chorale_179.csv',
#  'chorales\\train\\chorale_180.csv',
#  'chorales\\train\\chorale_181.csv',
#  'chorales\\train\\chorale_182.csv',
#  'chorales\\train\\chorale_183.csv',
#  'chorales\\train\\chorale_184.csv',
#  'chorales\\train\\chorale_185.csv',
#  'chorales\\train\\chorale_186.csv',
#  'chorales\\train\\chorale_187.csv',
#  'chorales\\train\\chorale_188.csv',
#  'chorales\\train\\chorale_189.csv',
#  'chorales\\train\\chorale_190.csv',
#  'chorales\\train\\chorale_191.csv',
#  'chorales\\train\\chorale_192.csv',
#  'chorales\\train\\chorale_193.csv',
#  'chorales\\train\\chorale_194.csv',
#  'chorales\\train\\chorale_195.csv',
#  'chorales\\train\\chorale_196.csv',
#  'chorales\\train\\chorale_197.csv',
#  'chorales\\train\\chorale_198.csv',
#  'chorales\\train\\chorale_199.csv',
#  'chorales\\train\\chorale_200.csv',
#  'chorales\\train\\chorale_201.csv',
#  'chorales\\train\\chorale_202.csv',
#  'chorales\\train\\chorale_203.csv',
#  'chorales\\train\\chorale_204.csv',
#  'chorales\\train\\chorale_205.csv',
#  'chorales\\train\\chorale_206.csv',
#  'chorales\\train\\chorale_207.csv',
#  'chorales\\train\\chorale_208.csv',
#  'chorales\\train\\chorale_209.csv',
#  'chorales\\train\\chorale_210.csv',
#  'chorales\\train\\chorale_211.csv',
#  'chorales\\train\\chorale_212.csv',
#  'chorales\\train\\chorale_213.csv',
#  'chorales\\train\\chorale_214.csv',
#  'chorales\\train\\chorale_215.csv',
#  'chorales\\train\\chorale_216.csv',
#  'chorales\\train\\chorale_217.csv',
#  'chorales\\train\\chorale_218.csv',
#  'chorales\\train\\chorale_219.csv',
#  'chorales\\train\\chorale_220.csv',
#  'chorales\\train\\chorale_221.csv',
#  'chorales\\train\\chorale_222.csv',
#  'chorales\\train\\chorale_223.csv',
#  'chorales\\train\\chorale_224.csv',
#  'chorales\\train\\chorale_225.csv',
#  'chorales\\train\\chorale_226.csv',
#  'chorales\\train\\chorale_227.csv',
#  'chorales\\train\\chorale_228.csv']

# %%
# each chorale is a list of lists on integers
train_data = [pd.read_csv(f).values.tolist() for f in train_files]
test_data = [pd.read_csv(f).values.tolist() for f in test_files]
valid_data = [pd.read_csv(f).values.tolist() for f in valid_files]

# %% [markdown]
# 36 = C1,
# 81 = A5,
# 0 = silence

# %%
chorale = train_data[20] # example

s = stream.Stream()
for row in chorale:
    # loop through each time step of the chorale and then each note
    # if the note isn't silence, add it to the chord, length 1 quarter note
    # add the chord to the musical stream
    s.append(chord.Chord([n for n in row if n], quarterLength=1))

# show the MIDI player
s.show("midi")
# Out:
#         <div id="midiPlayerDiv988"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv988_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv988");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv988_play, 2000);
#         } else {
#             midiPlayerDiv988_play();
#         }
#         </script>

# %% [markdown]
# ### Preprocessing

# %%
min_note, max_note = 36, 81

# window_size = 32 -> train model on sequences of 32 time steps
# window_offset = 16 -> how far we slide the window each time
# batch_size = 32 -> how many windows we'll train at once
window_size, window_offset, batch_size = 32, 16, 32

def make_xy(chorales):
    # shape: (num_windows, window_size + 1, num_voices)
    windows = [c[i:i + window_size + 1] 
               for c in chorales 
               for i in range(0, len(c) - window_size, window_offset)]
    
    data = np.array(windows, dtype=int)

    # np.where(condition, value_if_true, value_if_false)
    data = np.where(data == 0, 0, data - min_note + 1)
    # clip data between 0 and max_note - min_note + 1
    data = np.clip(data, 0, max_note - min_note + 1)

    # new shape (num_windows, (window_size + 1) * num_voices)
    # flattens so each chorale timestep row is joined
    flat = data.reshape(data.shape[0], -1) 

    # X and Y have shape (num_windows, (window_size + 1) * num_voices - 1)
    return flat[:, :-1], flat[:, 1:]

X_train, Y_train = make_xy(train_data)
X_test, Y_test = make_xy(test_data)
X_valid, Y_valid = make_xy(valid_data)

# %%
X_train.shape
# Out:
# (3111, 131)

# %% [markdown]
# ### Training Model

# %%
from tensorflow.keras.models import Sequential  # linear stack of layers
from tensorflow.keras.layers import Conv1D, Dense, Embedding, LSTM, Dropout, BatchNormalization
# Conv1D → learns local sequence patterns (sliding window)
# Dense → fully connected layer
# Embedding → maps integer tokens (notes) to dense vectors
# LSTM → recurrent layer for long-term sequence dependencies
# Dropout → randomly drop neurons to reduce overfitting
# BatchNormalization → normalizes activations for stable training

from tensorflow.keras.optimizers import Nadam  # Adam + Nesterov momentum optimizer

# %%
model = Sequential()

# input_dim = 47 = 46 + the silence
# output_dim = 5 maps each note to a vector of length 5, instead of one hot encoding for a length 47
# 5 is smaller, more trainable, captures similarity between notes, e.g. octaves or 5ths
# input_shape = [None] means it can take a sequence of any length
model.add(Embedding(input_dim=47, output_dim=5, input_shape=[None]))

# 32 filters, output will have 32 channels per time step
# kernel_size=2 -> the filter looks at 2 consecutive time steps at a time
# padding="casual" -> ensures convolution only uses past and current time steps
# relu activation
model.add(Conv1D(32, kernel_size=2, padding="causal", activation="relu"))
# normalize the activations -> zero mean, unit variance, helps speed up convergence and prevent exploding gradients
model.add(BatchNormalization())

# dilation_rate=2 means the kenrel skips every other note [note_t, note_(t+2)]
# dilation=1 → sees 2 consecutive notes
# dilation=2 → sees 4 notes apart
# dilation=4 → sees 8 notes apart
# dilation=8 → sees 16 notes apart
# dilation=16 → sees 32 notes apart
model.add(Conv1D(48, kernel_size=2, padding="causal", activation="relu", dilation_rate=2))
model.add(BatchNormalization())
model.add(Conv1D(64, kernel_size=2, padding="causal", activation="relu", dilation_rate=4))
model.add(BatchNormalization())
model.add(Conv1D(96, kernel_size=2, padding="causal", activation="relu", dilation_rate=8))
model.add(BatchNormalization())
model.add(Conv1D(128, kernel_size=2, padding="causal", activation="relu", dilation_rate=16))
model.add(BatchNormalization())

# dropout 5% of the neurons during each training step
model.add(Dropout(0.05))
# 256 units -> size of the hidden state
# return_sequences=True -> returns output for every time step, not just the last
model.add(LSTM(256, return_sequences=True))
# 47 -> number of neurons in the Dense layer, output softmax probs for each note
model.add(Dense(47, activation="softmax"))
# final shape is (batch_size, seq_length, 47)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, None, 5)             │             235 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_5 (Conv1D)                    │ (None, None, 32)            │             352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, None, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_6 (Conv1D)                    │ (None, None, 48)            │           3,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, None, 48)            │             192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_7 (Conv1D)                    │ (None, None, 64)            │           6,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, None, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_8 (Conv1D)                    │ (None, None, 96)            │          12,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, None, 96)            │             384 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_9 (Conv1D)                    │ (None, None, 128)           │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, None, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, None, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, None, 256)           │         394,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, None, 47)            │          12,079 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 454,794 (1.73 MB)
#  Trainable params: 454,058 (1.73 MB)
#  Non-trainable params: 736 (2.88 KB)

# %%
# ran this in google colab with a T4 GPU
optimizer = Nadam(learning_rate=1e-3)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
model.fit(X_train, Y_train, epochs=10, validation_data=[X_valid, Y_valid], batch_size=batch_size)

# %%
from tensorflow.keras.models import load_model
model = load_model("music_model.keras") # loaded the model ran on Google Colab

# %%
def sample_next_note(probs):
    # probs is 1D array of length 47, each element is probability
    probabilities = np.asarray(probs, dtype=float) # convert to numpy array

    prob_sum = probabilities.sum()

    if prob_sum <= 0 or not np.isfinite(prob_sum):
        # if the sum of probs is 0 or not finite (NaN or Inf), something went wrong
        # just pick highest prob note
        return int(np.argmax(probabilities))

    # normalize the probs to sum to 1 exactly
    probabilities /= prob_sum

    # randomly select index accoring to the probabilities, generates variation
    return np.random.choice(len(probabilities), p=probabilities)

# %%
def generate_chorale(model, seed_chords, length):
    # model -> trained neural network
    # seed_chords -> small initial sequence of chords (list of lists), used to prime the network
    # length -> how many chords to generate
    
    token_sequence = np.array(seed_chords, dtype=int) # turn into numpy array
    # rescaling to match model training
    token_sequence = np.where(token_sequence == 0, 0, token_sequence - min_note + 1)
    # flatten: 1 -> batch size, -1 -> atuo flatten everything into single dimension
    # if token_sequence has shape (num_seed_chords, num_voices) -> (1, num_seed_chords * num_voices)
    token_sequence = token_sequence.reshape(1, -1)

    for _ in range(length * 4):
        # length = num chords to generate, multiply by 4 because each chord has 4 voices

        # input: (1, seq_length)
        # output: (1, seq_length, 47) -> softmax probs for the next note over 47 posssible notes for every timestep
        # [0, -1] -> 0 takes the only batch, -1 takes the last probability vecotr, shape (47,)
        next_token_probabilities = model.predict(token_sequence, verbose=0)[0, -1]
        # sample the next note
        next_token = sample_next_note(next_token_probabilities)
        #concatenate onto the chorale: [[next_token]] shape (1, 1) to match the batch dimension
        # axis=1 to add the new note at the end of the sequence
        token_sequence = np.concatenate([token_sequence, [[next_token]]], axis=1)

    # convert the notes back to the actual MIDI nums
    token_sequence = np.where(token_sequence == 0, 0, token_sequence + min_note - 1)

    # reshape, 4 columns for the 4 voices. -1 means figure out the row dimension
    return token_sequence.reshape(-1, 4)

# %%
chorale = test_data[2] # the third chorale in the test set

s = stream.Stream()
for row in chorale:
    # add the chords to the stream
    s.append(chord.Chord([n for n in row if n], quarterLength=1))

s.show("midi")
# Out:
#         <div id="midiPlayerDiv5651"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv5651_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv5651");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv5651_play, 2000);
#         } else {
#             midiPlayerDiv5651_play();
#         }
#         </script>

# %%
seed_chords = test_data[2][:8] # take the first 8 timesteps for generation
new_chorale = generate_chorale(model, seed_chords, 56) # generate 56 new chords
new_chorale
# Out:
# array([[73, 68, 61, 53],
#        [73, 68, 61, 53],
#        [73, 68, 61, 53],
#        [73, 68, 61, 53],
#        [69, 66, 61, 54],
#        [69, 66, 61, 54],
#        [69, 66, 61, 54],
#        [69, 66, 61, 54],
#        [68, 64, 59, 52],
#        [68, 64, 59, 52],
#        [68, 62, 59, 52],
#        [68, 62, 59, 52],
#        [64, 61, 61, 49],
#        [64, 61, 61, 49],
#        [64, 61, 61, 49],
#        [64, 61, 61, 49],
#        [69, 61, 59, 51],
#        [69, 61, 59, 51],
#        [69, 61, 59, 54],
#        [69, 61, 59, 54],
#        [68, 61, 59, 52],
#        [68, 61, 59, 52],
#        [68, 61, 59, 52],
#        [68, 61, 59, 52],
#        [66, 61, 57, 57],
#        [66, 61, 57, 57],
#        [66, 61, 57, 54],
#        [66, 61, 57, 54],
#        [73, 64, 59, 56],
#        [73, 64, 59, 56],
#        [73, 64, 61, 56],
#        [73, 64, 61, 56],
#        [74, 66, 59, 53],
#        [74, 66, 59, 53],
#        [74, 66, 59, 53],
#        [74, 66, 59, 53],
#        [73, 64, 61, 52],
#        [73, 64, 61, 52],
#        [73, 64, 59, 52],
#        [73, 64, 59, 52],
#        [69, 64, 61, 61],
#        [69, 64, 61, 61],
#        [69, 64, 61, 61],
#        [69, 64, 61, 61],
#        [69, 66, 66, 50],
#        [69, 66, 66, 50],
#        [69, 66, 66, 49],
#        [69, 66, 66, 49],
#        [76, 68, 65, 47],
#        [76, 68, 65, 47],
#        [76, 68, 61, 44],
#        [76, 68, 61, 45],
#        [74, 66, 62, 66],
#        [74, 66, 62, 66],
#        [74, 69, 59, 54],
#        [74, 69, 59, 54],
#        [74, 71, 59, 53],
#        [74, 71, 59, 53],
#        [74, 71, 64, 51],
#        [74, 71, 64, 51],
#        [76, 66, 60, 54],
#        [76, 66, 60, 54],
#        [79, 68, 59, 52],
#        [79, 68, 59, 52]])

# %%
chorale = new_chorale.tolist()
s = stream.Stream()
for row in chorale:
    s.append(chord.Chord([n for n in row if n], quarterLength=1))

s.show("midi")
# Out:
#         <div id="midiPlayerDiv5980"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv5980_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv5980");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv5980_play, 2000);
#         } else {
#             midiPlayerDiv5980_play();
#         }
#         </script>
